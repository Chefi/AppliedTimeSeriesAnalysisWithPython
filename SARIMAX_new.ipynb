# %% [markdown]
# # SARIMAX

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

from sklearn.metrics import mean_squared_error

from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [10, 7.5]

# %% [markdown]
# ## United States Macroeconomic Dataset

# %%
macro_data = sm.datasets.macrodata.load_pandas()

# %%
macro_data.data
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# 0     28.980   139.7      2.82    5.8  177.146  0.00     0.00
# 1     29.150   141.7      3.08    5.1  177.830  2.34     0.74
# 2     29.350   140.5      3.82    5.3  178.657  2.74     1.09
# 3     29.370   140.0      4.33    5.6  179.386  0.27     4.06
# 4     29.540   139.6      3.50    5.2  180.007  2.31     1.19
# ..       ...     ...       ...    ...      ...   ...      ...
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
macro_data = macro_data.data

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=100, figsize=(5,5))

for i, ax in enumerate(axes.flatten()):
    data = macro_data[macro_data.columns[i+2]]
    
    ax.plot(data, color='black', linewidth=1)
    #ax.set_title(macro_data.columns[i+2])
    #ax.xaxis.set_ticks_position('none')
    #ax.yaxis.set_ticks_position('none')
    #ax.spines['top'].set_alpha(0)
    #ax.tick_params(labelsize=6)
    
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Generate sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# 2. Create a figure with 1 row and 2 columns
# figsize sets the width and height of the total canvas in inches
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# 3. Plot data on the first subplot
ax1.plot(x, y1, color='blue')
ax1.set_title('Sine Wave')
ax1.set_xlabel('X axis')
ax1.set_ylabel('Y axis')

# 4. Plot data on the second subplot
ax2.plot(x, y2, color='red')
ax2.set_title('Cosine Wave')
ax2.set_xlabel('X axis')

# 5. Clean up layout and display
fig.suptitle('1D Subplots Example', fontsize=16) # Add an overall title
plt.tight_layout() # Adjusts spacing so titles/labels don't overlap
plt.show()

# %%
macro_data['realgdp_tr1'] = macro_data['realgdp'].diff()

macro_data.head(10)
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
# 5  1960.0      2.0  2834.390    1792.9  298.152   460.400   1966.1  29.55
# 6  1960.0      3.0  2839.022    1785.8  296.375   474.676   1967.8  29.75
# 7  1960.0      4.0  2802.616    1788.2  259.764   476.434   1966.6  29.84
# 8  1961.0      1.0  2819.264    1787.7  266.405   475.854   1984.5  29.81
# 9  1961.0      2.0  2872.005    1814.3  286.246   480.328   2014.4  29.92
#
#       m1  tbilrate  unemp      pop  infl  realint  realgdp_tr1
# 0  139.7      2.82    5.8  177.146  0.00     0.00          NaN
# 1  141.7      3.08    5.1  177.830  2.34     0.74       68.452
# 2  140.5      3.82    5.3  178.657  2.74     1.09       -3.313
# 3  140.0      4.33    5.6  179.386  0.27     4.06        9.716
# 4  139.6      3.50    5.2  180.007  2.31     1.19       62.495
# 5  140.2      2.68    5.2  180.671  0.14     2.55      -13.309
# 6  140.9      2.36    5.6  181.528  2.70    -0.34        4.632
# 7  141.1      2.29    6.3  182.287  1.21     1.08      -36.406
# 8  142.1      2.37    6.8  182.992 -0.40     2.77       16.648
# 9  142.9      2.29    7.0  183.691  1.47     0.81       52.741

# %%
plt.plot(macro_data['realgdp_tr1'])
plt.title('Transformed RealGDP')
plt.show()

# %%
ad_fuller_result = adfuller(macro_data['realgdp_tr1'][1:])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -6.305695561658106
# p-value: 3.327882187668224e-08

# %%
plot_acf(macro_data['realgdp_tr1'][1:]);
plot_pacf(macro_data['realgdp_tr1'][1:]);

# %%
def optimize_SARIMAX(endog, exog, parameters_list, d, D, s):
    """
        Returns dataframe with parameters, corresponding AIC
        
        endog - the observed variable
        exog - the exogenous variables
        parameters_list - list with (p, d, P, Q)tuples
        d - integration order
        D - seasonal integration order
        s - length of the season
    """
    
    results = []
    
    for param in tqdm_notebook(parameters_list):
        try:
            model = SARIMAX(endog,
                           exog,
                           order=(param[0], d, param[1]),
                           seasonal_order=(param[2], D, param[3], s),
                           simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([param, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 0
Q = range(0, 4, 1)
s = 4

parameters = product(p, q, P, Q)
parameters_list = list(parameters)

# %%
endog = macro_data['realgdp'][:200]
exog = macro_data[['realcons', 'realinv', 'realgovt', 'realdpi', 'cpi', 'm1', 'tbilrate', 'unemp', 'pop', 'infl', 'realint']][:200]

result_df = optimize_SARIMAX(endog, exog, parameters_list, 1, 0, 4)
result_df
# Out:
# HBox(children=(IntProgress(value=0, max=256), HTML(value='')))
#       (p,q)x(P,Q)          AIC
# 0    (2, 2, 1, 0)  1757.109287
# 1    (3, 3, 0, 0)  1757.884228
# 2    (2, 2, 0, 2)  1758.327884
# 3    (2, 2, 0, 0)  1759.100314
# 4    (2, 2, 2, 0)  1759.529891
# ..            ...          ...
# 251  (3, 2, 2, 1)  1776.806697
# 252  (3, 2, 1, 3)  1776.867114
# 253  (3, 2, 1, 1)  1776.944895
# 254  (3, 2, 1, 2)  1778.132129
# 255  (3, 2, 3, 1)  1778.371677
#
# [256 rows x 2 columns]

# %%
best_model = SARIMAX(endog, 
                     exog, 
                     order=(2,1,2), 
                     seasonal_order=(1,0,0,4),
                    simple_differencing=False)
res = best_model.fit(dis=False)

print(res.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            realgdp   No. Observations:                  200
# Model:             SARIMAX(2, 1, 2)x(1, 0, [], 4)   Log Likelihood                -861.555
# Date:                            Sun, 20 Dec 2020   AIC                           1757.109
# Time:                                    11:22:03   BIC                           1813.095
# Sample:                                         0   HQIC                          1779.768
#                                             - 200
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# realcons       0.9576      0.054     17.601      0.000       0.851       1.064
# realinv        0.9954      0.042     23.516      0.000       0.912       1.078
# realgovt       0.7295      0.139      5.238      0.000       0.457       1.002
# realdpi        0.0095      0.024      0.395      0.693      -0.038       0.057
# cpi            5.3583      2.070      2.588      0.010       1.301       9.416
# m1             0.0054      0.160      0.034      0.973      -0.308       0.318
# tbilrate      -3.7295     23.852     -0.156      0.876     -50.479      43.020
# unemp         -7.9184      5.745     -1.378      0.168     -19.178       3.341
# pop            5.7601      7.567      0.761      0.447      -9.072      20.592
# infl          -0.6144     23.742     -0.026      0.979     -47.147      45.919
# realint       -0.4631     23.697     -0.020      0.984     -46.909      45.983
# ar.L1          1.8102      0.053     33.883      0.000       1.706       1.915
# ar.L2         -0.8839      0.056    -15.895      0.000      -0.993      -0.775
# ma.L1         -1.8091      0.040    -45.047      0.000      -1.888      -1.730
# ma.L2          0.9393      0.037     25.320      0.000       0.867       1.012
# ar.S.L4        0.0863      0.069      1.246      0.213      -0.049       0.222
# sigma2       326.0051     30.100     10.831      0.000     267.011     385.000
# ===================================================================================
# Ljung-Box (Q):                       26.49   Jarque-Bera (JB):                14.31
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.84   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.plot_diagnostics();

# %%
n_forecast = 3
predict = res.get_prediction(end=best_model.nobs + n_forecast,
                            exog = exog.iloc[-4:])
idx = np.arange(len(predict.predicted_mean))
predict_ci = predict.conf_int(alpha=0.5)

fig, ax = plt.subplots()
ax.plot(macro_data['realgdp'][:199], color='blue')
ax.plot(idx[-n_forecast:], predict.predicted_mean[-n_forecast:], 'k--')
ax.fill_between(idx, predict_ci.iloc[:,0], predict_ci.iloc[:,1], alpha=0.15)

ax.set_title('Forecast of US Real GDP')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(macro_data['realgdp'], color='blue')
ax.plot(idx[-n_forecast:], predict.predicted_mean[-n_forecast:], 'k--')
ax.plot(predict.predicted_mean, 'ro')
ax.fill_between(idx, predict_ci.iloc[:,0], predict_ci.iloc[:,1], alpha=0.15)
ax.set_xlim(190,199)
ax.set_ylim(13000, 14100)

ax.set_title('Forcaset of RealGDP')
plt.show()

# %%
mse = mean_squared_error(macro_data['realgdp'], predict.predicted_mean[:203])

print(f'MSE: {mse}')
# Out:
# MSE: 6850.346552663639

# %%
mape = np.mean(np.abs(macro_data['realgdp'] - predict.predicted_mean[:203]) / np.abs(macro_data['realgdp']))

print(f'MAPE: {round(mape * 100, 2)}%')
# Out:
# MAPE: 0.39%
